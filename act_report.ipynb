# %% [markdown]
# # Insights and Visualisation Report

# %% [markdown]
# ### Insights on Retweets

# %% [markdown]
# ##### Most Retweet<br>
# > The doggo below, whose dog breed is labrador retriever had the highest number of retweets with 70,747 retweets.
# - Tweet id: 744234799360020481
# - Tweet text: Here's a doggo realizing you can stand in a pool. 13/10 enlightened af (vid by Tina Conrad)

# %% [markdown]
# ![highest%20retweet.jpg](attachment:highest%20retweet.jpg)

# %% [markdown]
# ##### Least Retweet
# >The english setter displayed below had the least number of retweets with just 11 retweets.
# - Tweet id: 66102155909144576
# - Tweet text: Oh my. Here you are seeing an Adobe Setter giving birth to twins!!! The world is an amazing place. 11/10

# %% [markdown]
# ![least%20retweet.jpg](attachment:least%20retweet.jpg)

# %% [markdown]
# ### Insights on Favorites

# %% [markdown]
# ##### Most favorites
#
# > The same dog with the most retweets had the most favorites

# %% [markdown]
# ##### Least favorites
#
# > 70 different tweet images had 0 favorite count making them the tweet images with the least number of favorites

# %% [markdown]
# ### Insights on dog prediction test

# %% [markdown]
# > Of the 1922 tweets, **1676** tweet images were predicted to be dogs while **246** images were predicted to not be a dog based on the most confident prediction test (p1_conf).

# %% [markdown]
# ![IMAGE%20PREDICTION.png](attachment:IMAGE%20PREDICTION.png)

# %% [markdown]
# ### Insights on Numerator ratings

# %% [markdown]
# >The lowest numerator rating given was 7 while the highest numerator rating given was 15. **470** tweet images were rated with a numerator score of **12**, making it the most frequently given numerator rating.

# %% [markdown]
# ![RATING.png](attachment:RATING.png)

# %% [markdown]
# ### Insights on highest rated tweet image

# %% [markdown]
# > The tweet image below had a rating score of **15** making it the highest rated tweet image. It however didn't interest twitter users as it received very low favorites and retweets count.
# - Tweet id: 838916489579200512
# - Tweet text: RT @KibaDva: I collected all the good dogs!! 15/10 @dog_rates #GoodDogs
# - Retweets:  31
# - Favorites: 0

# %% [markdown]
# ![highest%20rating%20by%20image.jpg](attachment:highest%20rating%20by%20image.jpg)

# %% [markdown]
# ### Insights on tweets per year

# %% [markdown]
# > **2016** with **972** tweets was the year with the highest number of tweets

# %% [markdown]
# ![Tweet%20year.png](attachment:Tweet%20year.png)

# %% [markdown]
# ### Insights on tweet by month over the three years

# %% [markdown]
# > December was the busiest month over the three years. It had a total of 386 tweets.
# > The first 3 months and last 2 months of the calendar year make up the top 5 months indicating that more tweets were seen to be tweeted during the start and end of the years.

# %% [markdown]
# ![tweet%20month.png](attachment:tweet%20month.png)

# %% [markdown]
# ### Insights on correlation between favorite count and Retweet count

# %% [markdown]
# >There is a clear upward movement as the clustering of data points moved from left to right indicating a positive correlation between retweet count and favorite count. This shows that the higher the number of retweets, the more likely there is also an increase in the number of favorites and vice versa.

# %% [markdown]
# ![correlation.png](attachment:correlation.png)

# %% [markdown]
# ### Insights on dog breeds based on most confident algorithm(p1)

# %% [markdown]
# **148** tweet images were predicted to be **Golden retriever**, making it the most common dog breed. In addition to Golden retriever, Labrador retriever with 94 tweet images and Pembroke with 84 tweet images make up the top 3 dog breeds.

# %% [markdown]
# ![dog%20breed.png](attachment:dog%20breed.png)
